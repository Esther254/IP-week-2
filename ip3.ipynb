# %%
import pandas as pd
df=pd.read_csv("pokemon.csv")
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
#finding missing values present on the data
df.isnull()
# Out:
#      abilities  against_bug  against_dark  against_dragon  against_electric  \
# 0        False        False         False           False             False
# 1        False        False         False           False             False
# 2        False        False         False           False             False
# 3        False        False         False           False             False
# 4        False        False         False           False             False
# ..         ...          ...           ...             ...               ...
# 796      False        False         False           False             False
# 797      False        False         False           False             False
# 798      False        False         False           False             False
# 799      False        False         False           False             False
# 800      False        False         False           False             False
#
# ...

# %%
#number of missing values across each column
df.isnull().sum()
# Out:
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# percentage_male       98
# pokedex_number         0
# sp_attack              0
# sp_defense             0
# speed                  0
# type1                  0
# ...

# %%
#dropping all cols with  all N/A values
all_cols_all_na=df.dropna(axis=1,how="all")
print(all_cols_all_na)
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
#dropping all rows with all N/A values
all_rows_all_na=df.dropna()
print(all_rows_all_na)
# Out:
#                                       abilities  against_bug  against_dark  \
# 0                   ['Overgrow', 'Chlorophyll']         1.00           1.0
# 1                   ['Overgrow', 'Chlorophyll']         1.00           1.0
# 2                   ['Overgrow', 'Chlorophyll']         1.00           1.0
# 5                      ['Blaze', 'Solar Power']         0.25           1.0
# 11              ['Compoundeyes', 'Tinted Lens']         0.50           1.0
# ..                                          ...          ...           ...
# 777                                ['Disguise']         0.25           1.0
# 778  ['Dazzling', 'Strong Jaw', 'Wonder Skin ']         2.00           2.0
# 779     ['Berserk', 'Sap Sipper', 'Cloud Nine']         1.00           1.0
# 782   ['Bulletproof', 'Soundproof', 'Overcoat']         0.50           0.5
# 783   ['Bulletproof', 'Soundproof', 'Overcoat']         0.50           0.5
#
# ...

# %%
df.shape
# Out:
# (801, 41)

# %%
df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
#finding outliers 
#import required libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.boxplot(column=["against_fire"],by="against_bug",grid=False)

# %%
#dealing with outliers
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df_out=df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]
#printing out the shape of our new dataset
print(df_out.shape)
#printing out the shape of our old dataset
print(df.shape)
# Out:
# (4, 41)
# (801, 41)

# %%
#dealing with duplicated values
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
# fitting label encoder method in the column of the data
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
label_encoder.fit(df["type1"])
# Out:
# LabelEncoder()

# %%
#view labels in the column
list(label_encoder.classes_)
#transform categories into integers
df["type1"]=label_encoder.transform(df["type1"])
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
#renaming columns
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
df.rename(columns={'against_dark':"light","against_electric":"power",'against_fight':"stop_fight"},inplace=True)
df.head()
# Out:
#                      abilities  against_bug  light  against_dragon  power  \
# 0  ['Overgrow', 'Chlorophyll']          1.0    1.0             1.0    0.5
# 1  ['Overgrow', 'Chlorophyll']          1.0    1.0             1.0    0.5
# 2  ['Overgrow', 'Chlorophyll']          1.0    1.0             1.0    0.5
# 3     ['Blaze', 'Solar Power']          0.5    1.0             1.0    1.0
# 4     ['Blaze', 'Solar Power']          0.5    1.0             1.0    1.0
#
#    against_fairy  stop_fight  against_fire  against_flying  against_ghost  \
# 0            0.5         0.5           2.0             2.0            1.0
# 1            0.5         0.5           2.0             2.0            1.0
# 2            0.5         0.5           2.0             2.0            1.0
# 3            0.5         1.0           0.5             1.0            1.0
# 4            0.5         1.0           0.5             1.0            1.0
#
# ...
